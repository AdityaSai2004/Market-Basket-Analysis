# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from apyori import apriori

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('cleaned.csv')
df.head()
# Out:
#    Unnamed: 0  BillNo                   Itemname  Quantity        Date  Price  \
# 0       41242  539993    JUMBO BAG PINK POLKADOT        10  2011-01-04   1.95
# 1       41243  539993         BLUE POLKADOT WRAP        25  2011-01-04   0.42
# 2       41244  539993         RED RETROSPOT WRAP        25  2011-01-04   0.42
# 3       41245  539993    RECYCLING BAG RETROSPOT         5  2011-01-04   2.10
# 4       41246  539993  RED RETROSPOT SHOPPER BAG        10  2011-01-04   1.25
#
#    CustomerID         Country  Year  Month             Datetime  Total
# 0     13313.0  United Kingdom  2011      1  2011-01-04 10:00:00   19.5
# 1     13313.0  United Kingdom  2011      1  2011-01-04 10:00:00   10.5
# 2     13313.0  United Kingdom  2011      1  2011-01-04 10:00:00   10.5
# 3     13313.0  United Kingdom  2011      1  2011-01-04 10:00:00   10.5
# 4     13313.0  United Kingdom  2011      1  2011-01-04 10:00:00   12.5

# %% [markdown]
# # Trail 1

# %%
items=df.set_index(['BillNo']).stack()
items
# Out:
# BillNo
# 539993  Unnamed: 0                      41242
#         Itemname      JUMBO BAG PINK POLKADOT
#         Quantity                           10
#         Date                       2011-01-04
#         Price                            1.95
#                                ...
# 581587  Country                        France
#         Year                             2011
#         Month                              12
#         Datetime          2011-12-09 12:50:00
#         Total                           14.85
# Length: 5243029, dtype: object

# %%
item = pd.DataFrame(items)
item.rename(columns={0:'list'},inplace=True)
item.index.levels[0]
# Out:
# Index([539993, 540001, 540002, 540003, 540004, 540005, 540013, 540014, 540015,
#        540016,
#        ...
#        581578, 581579, 581580, 581581, 581582, 581583, 581584, 581585, 581586,
#        581587],
#       dtype='int64', name='BillNo', length=17868)

# %%
products=[]

for i in (item.index.levels[0]):
    product=item.loc[(i,['Itemname']),'list'].to_list()
    
    products.append(product)

# %%
products[0:5]
# Out:
# [['JUMBO BAG PINK POLKADOT',
#   'BLUE POLKADOT WRAP',
#   'RED RETROSPOT WRAP',
#   'RECYCLING BAG RETROSPOT',
#   'RED RETROSPOT SHOPPER BAG',
#   'JUMBO BAG RED RETROSPOT',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'JAM MAKING SET PRINTED',
#   'RECIPE BOX RETROSPOT',
#   'CHILDRENS APRON APPLES DESIGN',
#   'PEG BAG APPLES DESIGN',
#   'COFFEE MUG APPLES DESIGN',
#   'COFFEE MUG PEARS  DESIGN',
#   'WHITE HANGING HEART T-LIGHT HOLDER',
#   'SET OF 6 T-LIGHTS EASTER CHICKS',
#   'CAST IRON HOOK GARDEN FORK',
#   'LOVE HEART NAPKIN BOX'],
#  ['RED HANGING HEART T-LIGHT HOLDER',
#   'CERAMIC BOWL WITH LOVE HEART DESIGN',
#   'LARGE CAKE STAND HANGING HEARTS',
#   'PLACE SETTING WHITE HEART',
#   'DOORSTOP RETROSPOT HEART',
#   'GINGHAM HEART  DOORSTOP RED',
#   'CERAMIC CHERRY CAKE MONEY BANK',
#   'LOVE HEART POCKET WARMER',
#   'SWEETHEART CERAMIC TRINKET BOX'],
#  ['GARDEN METAL SIGN',
#   'RED KITCHEN SCALES',
#   'VICTORIAN SEWING BOX SMALL',
#   'VINTAGE SNAP CARDS'],
#  ['HANGING HEART ZINC T-LIGHT HOLDER',
#   'BREAD BIN DINER STYLE RED',
#   'IVORY KITCHEN SCALES',
#   'TRIPLE PHOTO FRAME CORNICE',
#   'JAM JAR WITH GREEN LID',
#   'JAM JAR WITH PINK LID',
#   'ENAMEL FLOWER JUG CREAM',
#   'PHOTO FRAME 3 CLASSIC HANGING',
#   'RED DINER WALL CLOCK',
#   'IVORY DINER WALL CLOCK',
#   'SINGLE HEART ZINC T-LIGHT HOLDER',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'FAMILY PHOTO FRAME CORNICE',
#   'JAM MAKING SET PRINTED',
#   '3 HOOK PHOTO SHELF ANTIQUE WHITE',
#   'HANGING HEART JAR T-LIGHT HOLDER',
#   'SWEETHEART CAKESTAND 3 TIER',
#   'SET OF 3 HEART COOKIE CUTTERS',
#   'BREAD BIN DINER STYLE IVORY',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'NATURAL SLATE HEART CHALKBOARD',
#   'HOMEMADE JAM SCENTED CANDLES'],
#  ['ANTIQUE SILVER TEA GLASS ETCHED']]

# %%
rules=apriori(transactions=products,min_support=0.003,min_confidence=0.8,min_lift=3,min_length=2,max_length=3)
rules
# Out:
# <generator object apriori at 0x000002AF9382C040>

# %%
results=list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'3 RAFFIA RIBBONS VINTAGE CHRISTMAS', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), support=0.0047011417058428475, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3 RAFFIA RIBBONS VINTAGE CHRISTMAS'}), items_add=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS"}), confidence=0.865979381443299, lift=79.35035685963521)]),
#  RelationRecord(items=frozenset({'BICYCLE PUNCTURE REPAIR KIT', 'CLASSIC BICYCLE CLIPS'}), support=0.004421311842399821, ordered_statistics=[OrderedStatistic(items_base=frozenset({'CLASSIC BICYCLE CLIPS'}), items_add=frozenset({'BICYCLE PUNCTURE REPAIR KIT'}), confidence=0.8061224489795917, lift=126.34908700322232)]),
#  RelationRecord(items=frozenset({'SMALL DOLLY MIX DESIGN ORANGE BOWL', 'BISCUITS SMALL BOWL LIGHT BLUE'}), support=0.008450861875979404, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BISCUITS SMALL BOWL LIGHT BLUE'}), items_add=frozenset({'SMALL DOLLY MIX DESIGN ORANGE BOWL'}), confidence=0.9096385542168675, lift=32.05803094032937)]),
#  RelationRecord(items=frozenset({'SMALL MARSHMALLOWS PINK BOWL', 'BISCUITS SMALL BOWL LIGHT BLUE'}), support=0.0076113722856503245, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BISCUITS SMALL BOWL LIGHT BLUE'}), items_add=frozenset({'SMALL MARSHMALLOWS PINK BOWL'}), confidence=0.819277108433735, lift=33.652513502285004)]),
#  RelationRecord(items=frozenset({'BLUE FELT EASTER EGG BASKET', 'CREAM FELT EASTER EGG BASKET'}), support=0.0033019923886277143, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BLUE FELT EASTER EGG BASKET'}), items_add=frozenset({'CREAM FELT EASTER EGG BASKET'}), confidence=0.855072463768116, lift=140.16912644595135)]),
#  RelationRecord(items=frozenset({'RED POLKADOT BEAKER', 'BLUE POLKADOT BEAKER'}), support=0.004029550033579583, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BLUE POLKADOT BEAKER'}), items_add=frozenset({'RED POLKADOT BEAKER'}), confidence=0.8275862068965516, lift=118.29848275862066)]),
#  RelationRecord(items=frozenset({'PINK VINTAGE SPOT BEAKER', 'BLUE VINTAGE SPOT BEAKER'}), support=0.008338929930602194, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK VINTAGE SPOT BEAKER'}), items_add=frozenset({'BLUE VINTAGE SPOT BEAKER'}), confidence=0.8010752688172044, lift=65.65877478543949)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', 'PARTY CONES CANDY DECORATION'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PARTY CONES CANDY DECORATION'}), items_add=frozenset({'BUTTON BOX'}), confidence=0.8333333333333334, lift=65.88495575221239)]),
#  RelationRecord(items=frozenset({'CHRISTMAS MUSICAL ZINC TREE', 'CHRISTMAS MUSICAL ZINC STAR'}), support=0.004253413924334005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'CHRISTMAS MUSICAL ZINC TREE'}), items_add=frozenset({'CHRISTMAS MUSICAL ZINC STAR'}), confidence=0.853932584269663, lift=127.15056179775283)]),
#  RelationRecord(items=frozenset({'CHRISTMAS TREE HEART DECORATION', 'CHRISTMAS TREE DECORATION WITH BELL'}), support=0.004533243787777031, ordered_statistics=[OrderedStatistic(items_base=frozenset({'CHRISTMAS TREE DECORATION WITH BELL'}), items_add=frozenset({'CHRISTMAS TREE HEART DECORATION'}), confidence=0.8709677419354839, lift=107.32725250278085)]),
#  RelationRecord(items=frozenset({'CHRISTMAS TREE STAR DECORATION', 'CHRISTMAS TREE DECORATION WITH BELL'}), support=0.0041974479516454, ordered_statistics=[OrderedStatistic(items_base=frozenset({'CHRISTMAS TREE DECORATION WITH BELL'}), items_add=frozenset({'CHRISTMAS TREE STAR DECORATION'}), confidence=0.8064516129032259, lift=89.50110198357044)]),
#  RelationRecord(items=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER'}), support=0.033635549585851805, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.8210382513661203, lift=16.12122140154927)]),
#  RelationRecord(items=frozenset({'HERB MARKER CHIVES', 'HERB MARKER BASIL'}), support=0.009290351466308484, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER CHIVES'}), items_add=frozenset({'HERB MARKER BASIL'}), confidence=0.8691099476439791, lift=71.56339421429777)]),
#  RelationRecord(items=frozenset({'HERB MARKER MINT', 'HERB MARKER BASIL'}), support=0.010577568838146407, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER BASIL'}), items_add=frozenset({'HERB MARKER MINT'}), confidence=0.8709677419354839, lift=71.06142288996907), OrderedStatistic(items_base=frozenset({'HERB MARKER MINT'}), items_add=frozenset({'HERB MARKER BASIL'}), confidence=0.863013698630137, lift=71.06142288996907)]),
#  RelationRecord(items=frozenset({'HERB MARKER BASIL', 'HERB MARKER PARSLEY'}), support=0.010633534810835012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER BASIL'}), items_add=frozenset({'HERB MARKER PARSLEY'}), confidence=0.8755760368663594, lift=73.10650760153322), OrderedStatistic(items_base=frozenset({'HERB MARKER PARSLEY'}), items_add=frozenset({'HERB MARKER BASIL'}), confidence=0.8878504672897196, lift=73.10650760153322)]),
#  RelationRecord(items=frozenset({'HERB MARKER ROSEMARY', 'HERB MARKER BASIL'}), support=0.010745466756212223, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER BASIL'}), items_add=frozenset({'HERB MARKER ROSEMARY'}), confidence=0.8847926267281107, lift=72.85472190957549), OrderedStatistic(items_base=frozenset({'HERB MARKER ROSEMARY'}), items_add=frozenset({'HERB MARKER BASIL'}), confidence=0.8847926267281107, lift=72.85472190957549)]),
#  RelationRecord(items=frozenset({'HERB MARKER THYME', 'HERB MARKER BASIL'}), support=0.010577568838146407, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER BASIL'}), items_add=frozenset({'HERB MARKER THYME'}), confidence=0.8709677419354839, lift=72.3834958739685), OrderedStatistic(items_base=frozenset({'HERB MARKER THYME'}), items_add=frozenset({'HERB MARKER BASIL'}), confidence=0.8790697674418605, lift=72.38349587396849)]),
#  RelationRecord(items=frozenset({'HERB MARKER MINT', 'HERB MARKER CHIVES'}), support=0.009738079247817328, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER CHIVES'}), items_add=frozenset({'HERB MARKER MINT'}), confidence=0.9109947643979058, lift=74.32718927060175)]),
#  RelationRecord(items=frozenset({'HERB MARKER CHIVES', 'HERB MARKER PARSLEY'}), support=0.009850011193194537, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER CHIVES'}), items_add=frozenset({'HERB MARKER PARSLEY'}), confidence=0.9214659685863874, lift=76.93810246122229), OrderedStatistic(items_base=frozenset({'HERB MARKER PARSLEY'}), items_add=frozenset({'HERB MARKER CHIVES'}), confidence=0.822429906542056, lift=76.9381024612223)]),
#  RelationRecord(items=frozenset({'HERB MARKER ROSEMARY', 'HERB MARKER CHIVES'}), support=0.009682113275128721, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER CHIVES'}), items_add=frozenset({'HERB MARKER ROSEMARY'}), confidence=0.9057591623036649, lift=74.58112770526213)]),
#  RelationRecord(items=frozenset({'HERB MARKER THYME', 'HERB MARKER CHIVES'}), support=0.009682113275128721, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER CHIVES'}), items_add=frozenset({'HERB MARKER THYME'}), confidence=0.9057591623036649, lift=75.27490563740412), OrderedStatistic(items_base=frozenset({'HERB MARKER THYME'}), items_add=frozenset({'HERB MARKER CHIVES'}), confidence=0.8046511627906976, lift=75.27490563740412)]),
#  RelationRecord(items=frozenset({'HERB MARKER MINT', 'HERB MARKER PARSLEY'}), support=0.010801432728900828, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER MINT'}), items_add=frozenset({'HERB MARKER PARSLEY'}), confidence=0.8812785388127854, lift=73.58263986685444), OrderedStatistic(items_base=frozenset({'HERB MARKER PARSLEY'}), items_add=frozenset({'HERB MARKER MINT'}), confidence=0.9018691588785046, lift=73.58263986685444)]),
#  RelationRecord(items=frozenset({'HERB MARKER MINT', 'HERB MARKER ROSEMARY'}), support=0.010857398701589433, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER MINT'}), items_add=frozenset({'HERB MARKER ROSEMARY'}), confidence=0.8858447488584474, lift=72.94135471245501), OrderedStatistic(items_base=frozenset({'HERB MARKER ROSEMARY'}), items_add=frozenset({'HERB MARKER MINT'}), confidence=0.8940092165898617, lift=72.94135471245502)]),
#  RelationRecord(items=frozenset({'HERB MARKER THYME', 'HERB MARKER MINT'}), support=0.010521602865457802, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER MINT'}), items_add=frozenset({'HERB MARKER THYME'}), confidence=0.858447488584475, lift=71.34297546989488), OrderedStatistic(items_base=frozenset({'HERB MARKER THYME'}), items_add=frozenset({'HERB MARKER MINT'}), confidence=0.8744186046511628, lift=71.34297546989488)]),
#  RelationRecord(items=frozenset({'HERB MARKER ROSEMARY', 'HERB MARKER PARSLEY'}), support=0.01091336467427804, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER PARSLEY'}), items_add=frozenset({'HERB MARKER ROSEMARY'}), confidence=0.9112149532710281, lift=75.03036306473147), OrderedStatistic(items_base=frozenset({'HERB MARKER ROSEMARY'}), items_add=frozenset({'HERB MARKER PARSLEY'}), confidence=0.8986175115207373, lift=75.03036306473147)]),
#  RelationRecord(items=frozenset({'HERB MARKER THYME', 'HERB MARKER PARSLEY'}), support=0.010745466756212223, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER PARSLEY'}), items_add=frozenset({'HERB MARKER THYME'}), confidence=0.897196261682243, lift=74.56326885459683), OrderedStatistic(items_base=frozenset({'HERB MARKER THYME'}), items_add=frozenset({'HERB MARKER PARSLEY'}), confidence=0.8930232558139536, lift=74.56326885459683)]),
#  RelationRecord(items=frozenset({'HERB MARKER THYME', 'HERB MARKER ROSEMARY'}), support=0.011305126483098277, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HERB MARKER ROSEMARY'}), items_add=frozenset({'HERB MARKER THYME'}), confidence=0.9308755760368664, lift=77.36225484942665), OrderedStatistic(items_base=frozenset({'HERB MARKER THYME'}), items_add=frozenset({'HERB MARKER ROSEMARY'}), confidence=0.9395348837209303, lift=77.36225484942665)]),
#  RelationRecord(items=frozenset({'SMALL DOLLY MIX DESIGN ORANGE BOWL', 'MIXED NUTS LIGHT GREEN BOWL'}), support=0.003246026415939109, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MIXED NUTS LIGHT GREEN BOWL'}), items_add=frozenset({'SMALL DOLLY MIX DESIGN ORANGE BOWL'}), confidence=0.9206349206349206, lift=32.445571522494596)]),
#  RelationRecord(items=frozenset({'SMALL MARSHMALLOWS PINK BOWL', 'MIXED NUTS LIGHT GREEN BOWL'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MIXED NUTS LIGHT GREEN BOWL'}), items_add=frozenset({'SMALL MARSHMALLOWS PINK BOWL'}), confidence=0.857142857142857, lift=35.20788177339901)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', 'PARTY CONES CANDY DECORATION'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PARTY CONES CANDY DECORATION'}), items_add=frozenset({'SKULL SHOULDER BAG'}), confidence=0.8484848484848485, lift=40.21413069688932)]),
#  RelationRecord(items=frozenset({'SUKI  SHOULDER BAG', 'PARTY CONES CANDY DECORATION'}), support=0.003413924334004925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PARTY CONES CANDY DECORATION'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.9242424242424242, lift=34.33339633339633)]),
#  RelationRecord(items=frozenset({"POPPY'S PLAYHOUSE BEDROOM", "POPPY'S PLAYHOUSE BATHROOM"}), support=0.009010521602865458, ordered_statistics=[OrderedStatistic(items_base=frozenset({"POPPY'S PLAYHOUSE BATHROOM"}), items_add=frozenset({"POPPY'S PLAYHOUSE BEDROOM"}), confidence=0.8214285714285714, lift=41.81562881562881)]),
#  RelationRecord(items=frozenset({"POPPY'S PLAYHOUSE BATHROOM", "POPPY'S PLAYHOUSE KITCHEN"}), support=0.009178419520931274, ordered_statistics=[OrderedStatistic(items_base=frozenset({"POPPY'S PLAYHOUSE BATHROOM"}), items_add=frozenset({"POPPY'S PLAYHOUSE KITCHEN"}), confidence=0.8367346938775511, lift=41.52993197278912)]),
#  RelationRecord(items=frozenset({"POPPY'S PLAYHOUSE BATHROOM", "POPPY'S PLAYHOUSE LIVINGROOM"}), support=0.009066487575554063, ordered_statistics=[OrderedStatistic(items_base=frozenset({"POPPY'S PLAYHOUSE BATHROOM"}), items_add=frozenset({"POPPY'S PLAYHOUSE LIVINGROOM"}), confidence=0.8265306122448979, lift=54.90129732190273)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE GREEN', 'REGENCY TEA PLATE PINK'}), support=0.01438325498097157, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK'}), items_add=frozenset({'REGENCY TEA PLATE GREEN'}), confidence=0.9113475177304966, lift=45.870302667066234)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE GREEN', 'REGENCY TEA PLATE ROSES'}), support=0.016565927915827176, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE GREEN'}), items_add=frozenset({'REGENCY TEA PLATE ROSES'}), confidence=0.8338028169014083, lift=35.81343445287107)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE ROSES', 'REGENCY TEA PLATE PINK'}), support=0.013935527199462727, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK'}), items_add=frozenset({'REGENCY TEA PLATE ROSES'}), confidence=0.8829787234042554, lift=37.92563420621932)]),
#  RelationRecord(items=frozenset({"ROLL WRAP 50'S CHRISTMAS", "ROLL WRAP 50'S RED CHRISTMAS"}), support=0.009570181329751511, ordered_statistics=[OrderedStatistic(items_base=frozenset({"ROLL WRAP 50'S RED CHRISTMAS"}), items_add=frozenset({"ROLL WRAP 50'S CHRISTMAS"}), confidence=0.8104265402843602, lift=41.373432633716995)]),
#  RelationRecord(items=frozenset({'SET/6 COLLAGE PAPER PLATES', 'SET/6 COLLAGE PAPER CUPS'}), support=0.008898589657488246, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SET/6 COLLAGE PAPER CUPS'}), items_add=frozenset({'SET/6 COLLAGE PAPER PLATES'}), confidence=0.8882681564245809, lift=74.51443858682822)]),
#  RelationRecord(items=frozenset({'SET/6 RED SPOTTY PAPER CUPS', 'SET/6 RED SPOTTY PAPER PLATES'}), support=0.01807700917841952, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SET/6 RED SPOTTY PAPER CUPS'}), items_add=frozenset({'SET/6 RED SPOTTY PAPER PLATES'}), confidence=0.8156565656565656, lift=29.622259177137224)]),
#  RelationRecord(items=frozenset({'SMALL DOLLY MIX DESIGN ORANGE BOWL', 'SMALL CHOCOLATES PINK BOWL'}), support=0.01102529661965525, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SMALL CHOCOLATES PINK BOWL'}), items_add=frozenset({'SMALL DOLLY MIX DESIGN ORANGE BOWL'}), confidence=0.8347457627118644, lift=29.418613980543576)]),
#  RelationRecord(items=frozenset({'SMALL MARSHMALLOWS PINK BOWL', 'SMALL CHOCOLATES PINK BOWL'}), support=0.010969330646966645, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SMALL CHOCOLATES PINK BOWL'}), items_add=frozenset({'SMALL MARSHMALLOWS PINK BOWL'}), confidence=0.8305084745762712, lift=34.11385154880187)]),
#  RelationRecord(items=frozenset({'SMALL MARSHMALLOWS PINK BOWL', 'SMALL LICORICE DES PINK BOWL'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SMALL LICORICE DES PINK BOWL'}), items_add=frozenset({'SMALL MARSHMALLOWS PINK BOWL'}), confidence=0.8333333333333334, lift=34.229885057471265)]),
#  RelationRecord(items=frozenset({'VINTAGE RED ENAMEL TRIM PLATE', 'VINTAGE RED TRIM ENAMEL BOWL'}), support=0.003413924334004925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'VINTAGE RED ENAMEL TRIM PLATE'}), items_add=frozenset({'VINTAGE RED TRIM ENAMEL BOWL'}), confidence=0.8026315789473684, lift=139.23709759836484)]),
#  RelationRecord(items=frozenset({'WOODEN TREE CHRISTMAS SCANDINAVIAN', 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), support=0.014271323035594358, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.8557046979865771, lift=32.88114310456809)]),
#  RelationRecord(items=frozenset({'GARDENERS KNEELING PAD CUP OF TEA', 'GARDENERS KNEELING PAD KEEP CALM', '12 PENCIL SMALL TUBE WOODLAND'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'GARDENERS KNEELING PAD CUP OF TEA', '12 PENCIL SMALL TUBE WOODLAND'}), items_add=frozenset({'GARDENERS KNEELING PAD KEEP CALM'}), confidence=0.8709677419354839, lift=17.196079130279806)]),
#  RelationRecord(items=frozenset({'PAPER CHAIN KIT VINTAGE CHRISTMAS', "PAPER CHAIN KIT 50'S CHRISTMAS", '12 PENCIL SMALL TUBE WOODLAND'}), support=0.003749720170136557, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PAPER CHAIN KIT VINTAGE CHRISTMAS', '12 PENCIL SMALL TUBE WOODLAND'}), items_add=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS"}), confidence=0.881578947368421, lift=16.057138258490262)]),
#  RelationRecord(items=frozenset({'SET OF 20 VINTAGE CHRISTMAS NAPKINS', "PAPER CHAIN KIT 50'S CHRISTMAS", '12 PENCIL SMALL TUBE WOODLAND'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SET OF 20 VINTAGE CHRISTMAS NAPKINS', '12 PENCIL SMALL TUBE WOODLAND'}), items_add=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS"}), confidence=0.9152542372881355, lift=16.670502254703777)]),
#  RelationRecord(items=frozenset({'SET 12 COLOURING PENCILS DOILY', 'SET 12 COLOUR PENCILS SPACEBOY', '12 PENCIL SMALL TUBE WOODLAND'}), support=0.003246026415939109, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SET 12 COLOURING PENCILS DOILY', '12 PENCIL SMALL TUBE WOODLAND'}), items_add=frozenset({'SET 12 COLOUR PENCILS SPACEBOY'}), confidence=0.8169014084507041, lift=52.50501570574526)]),
#  RelationRecord(items=frozenset({'VINTAGE HEADS AND TAILS CARD GAME', 'VINTAGE SNAP CARDS', '12 PENCIL SMALL TUBE WOODLAND'}), support=0.003413924334004925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'VINTAGE HEADS AND TAILS CARD GAME', '12 PENCIL SMALL TUBE WOODLAND'}), items_add=frozenset({'VINTAGE SNAP CARDS'}), confidence=0.8356164383561643, lift=18.29754230459307)]),
#  RelationRecord(items=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', 'WOODEN STAR CHRISTMAS SCANDINAVIAN', '12 PENCIL SMALL TUBE WOODLAND'}), support=0.003581822252070741, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', '12 PENCIL SMALL TUBE WOODLAND'}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.927536231884058, lift=35.64132772323516), OrderedStatistic(items_base=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN', '12 PENCIL SMALL TUBE WOODLAND'}), items_add=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), confidence=0.8767123287671234, lift=31.83962579351821)]),
#  RelationRecord(items=frozenset({'3 RAFFIA RIBBONS VINTAGE CHRISTMAS', 'WOODEN HEART CHRISTMAS SCANDINAVIAN', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3 RAFFIA RIBBONS VINTAGE CHRISTMAS', 'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS"}), confidence=0.9491525423728814, lift=86.9715775749674)]),
#  RelationRecord(items=frozenset({'3 RAFFIA RIBBONS VINTAGE CHRISTMAS', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3 RAFFIA RIBBONS VINTAGE CHRISTMAS', 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS"}), confidence=0.9491525423728814, lift=86.9715775749674)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), items_add=frozenset({'BUTTON BOX'}), confidence=0.8307692307692307, lift=65.68223281143635), OrderedStatistic(items_base=frozenset({'BUTTON BOX', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'ADVENT CALENDAR GINGHAM SACK'}), confidence=0.8852459016393442, lift=70.93082408292288)]),
#  RelationRecord(items=frozenset({'JAM MAKING SET PRINTED', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), items_add=frozenset({'JAM MAKING SET PRINTED'}), confidence=0.8307692307692307, lift=15.147127158555728), OrderedStatistic(items_base=frozenset({'JAM MAKING SET PRINTED', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'ADVENT CALENDAR GINGHAM SACK'}), confidence=0.8181818181818181, lift=65.55727680391358)]),
#  RelationRecord(items=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK', "JUMBO BAG 50'S CHRISTMAS"}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), items_add=frozenset({"JUMBO BAG 50'S CHRISTMAS"}), confidence=0.8307692307692307, lift=20.936790712813277)]),
#  RelationRecord(items=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK', 'NOEL GARLAND PAINTED ZINC'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), items_add=frozenset({'NOEL GARLAND PAINTED ZINC'}), confidence=0.8307692307692307, lift=124.741047188106), OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'NOEL GARLAND PAINTED ZINC'}), items_add=frozenset({'ADVENT CALENDAR GINGHAM SACK'}), confidence=0.8709677419354839, lift=69.78677853319833), OrderedStatistic(items_base=frozenset({'ADVENT CALENDAR GINGHAM SACK', 'NOEL GARLAND PAINTED ZINC'}), items_add=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS"}), confidence=0.8059701492537313, lift=73.85166475315728)]),
#  RelationRecord(items=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK', 'POPCORN HOLDER'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), items_add=frozenset({'POPCORN HOLDER'}), confidence=0.8307692307692307, lift=19.1044847044847)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), items_add=frozenset({'SKULL SHOULDER BAG'}), confidence=0.8769230769230769, lift=41.56196694552132), OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'ADVENT CALENDAR GINGHAM SACK'}), confidence=0.890625, lift=71.3618273542601), OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', 'ADVENT CALENDAR GINGHAM SACK'}), items_add=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS"}), confidence=0.8507462686567164, lift=77.95453501722157)]),
#  RelationRecord(items=frozenset({'SUKI  SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.8615384615384616, lift=32.00409403486327), OrderedStatistic(items_base=frozenset({'SUKI  SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'ADVENT CALENDAR GINGHAM SACK'}), confidence=0.875, lift=70.10986547085203)]),
#  RelationRecord(items=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), items_add=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), confidence=0.8307692307692307, lift=30.171106941838648)]),
#  RelationRecord(items=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK', 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'ADVENT CALENDAR GINGHAM SACK'}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.8461538461538461, lift=32.51414392059554)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', 'JAM MAKING SET PRINTED', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BUTTON BOX', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'JAM MAKING SET PRINTED'}), confidence=0.9016393442622952, lift=16.439277350284378), OrderedStatistic(items_base=frozenset({'JAM MAKING SET PRINTED', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'BUTTON BOX'}), confidence=0.8333333333333334, lift=65.88495575221239)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'SKULL SHOULDER BAG'}), support=0.003246026415939109, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BUTTON BOX', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'SKULL SHOULDER BAG'}), confidence=0.9508196721311476, lift=45.06431273644389), OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'BUTTON BOX'}), confidence=0.90625, lift=71.64988938053098)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'SUKI  SHOULDER BAG'}), support=0.0033019923886277143, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BUTTON BOX', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.9672131147540984, lift=35.929654749326886), OrderedStatistic(items_base=frozenset({'SUKI  SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'BUTTON BOX'}), confidence=0.921875, lift=72.88523230088497)]),
#  RelationRecord(items=frozenset({'JAM MAKING SET PRINTED', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'SKULL SHOULDER BAG'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JAM MAKING SET PRINTED', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'SKULL SHOULDER BAG'}), confidence=0.8636363636363636, lift=40.93224017361948), OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'JAM MAKING SET PRINTED'}), confidence=0.890625, lift=16.23845663265306)]),
#  RelationRecord(items=frozenset({'JAM MAKING SET PRINTED', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'SUKI  SHOULDER BAG'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JAM MAKING SET PRINTED', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.8484848484848485, lift=31.51918351918352), OrderedStatistic(items_base=frozenset({'SUKI  SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'JAM MAKING SET PRINTED'}), confidence=0.875, lift=15.953571428571427)]),
#  RelationRecord(items=frozenset({'JUMBO BAG VINTAGE CHRISTMAS', "3 RAFFIA RIBBONS 50'S CHRISTMAS", "JUMBO BAG 50'S CHRISTMAS"}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG VINTAGE CHRISTMAS', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({"JUMBO BAG 50'S CHRISTMAS"}), confidence=0.9333333333333333, lift=23.52157968970381)]),
#  RelationRecord(items=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'POPCORN HOLDER', "JUMBO BAG 50'S CHRISTMAS"}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'POPCORN HOLDER'}), items_add=frozenset({"JUMBO BAG 50'S CHRISTMAS"}), confidence=0.8088235294117647, lift=20.38372189496391)]),
#  RelationRecord(items=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'NOEL GARLAND PAINTED ZINC'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'NOEL GARLAND PAINTED ZINC'}), items_add=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), confidence=0.8709677419354839, lift=31.630999213217937)]),
#  RelationRecord(items=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'WOODEN STAR CHRISTMAS SCANDINAVIAN', 'NOEL GARLAND PAINTED ZINC'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'NOEL GARLAND PAINTED ZINC'}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.903225806451613, lift=34.707180020811656)]),
#  RelationRecord(items=frozenset({'PAPER CHAIN KIT VINTAGE CHRISTMAS', "3 RAFFIA RIBBONS 50'S CHRISTMAS", "PAPER CHAIN KIT 50'S CHRISTMAS"}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PAPER CHAIN KIT VINTAGE CHRISTMAS', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS"}), confidence=0.9344262295081968, lift=17.019702210858778)]),
#  RelationRecord(items=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", "PAPER CHAIN KIT 50'S CHRISTMAS", 'POPCORN HOLDER'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'POPCORN HOLDER'}), items_add=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS"}), confidence=0.8088235294117647, lift=14.7319661809678)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'POPCORN HOLDER'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'POPCORN HOLDER'}), items_add=frozenset({'SKULL SHOULDER BAG'}), confidence=0.8088235294117647, lift=38.334373537213295), OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'POPCORN HOLDER'}), confidence=0.859375, lift=19.76230694980695)]),
#  RelationRecord(items=frozenset({'SUKI  SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'POPCORN HOLDER'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SUKI  SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'POPCORN HOLDER'}), confidence=0.8437499999999999, lift=19.402992277992276)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'SUKI  SHOULDER BAG'}), support=0.00346989030669353, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.9687499999999999, lift=35.986746361746356), OrderedStatistic(items_base=frozenset({'SUKI  SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'SKULL SHOULDER BAG'}), confidence=0.9687499999999999, lift=45.91412466843501)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.859375, lift=33.02217741935484)]),
#  RelationRecord(items=frozenset({'SUKI  SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SUKI  SHOULDER BAG', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.8437499999999999, lift=32.42177419354838)]),
#  RelationRecord(items=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', "3 RAFFIA RIBBONS 50'S CHRISTMAS", 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), support=0.00430937989702261, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', "3 RAFFIA RIBBONS 50'S CHRISTMAS"}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.9166666666666666, lift=35.22365591397849), OrderedStatistic(items_base=frozenset({"3 RAFFIA RIBBONS 50'S CHRISTMAS", 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), confidence=0.9166666666666666, lift=33.290650406504064)]),
#  RelationRecord(items=frozenset({'3 RAFFIA RIBBONS VINTAGE CHRISTMAS', 'WOODEN HEART CHRISTMAS SCANDINAVIAN', 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3 RAFFIA RIBBONS VINTAGE CHRISTMAS', 'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.9491525423728814, lift=36.471951886276656), OrderedStatistic(items_base=frozenset({'3 RAFFIA RIBBONS VINTAGE CHRISTMAS', 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), confidence=0.9491525423728814, lift=34.47044233154196)]),
#  RelationRecord(items=frozenset({'36 PENCILS TUBE RED RETROSPOT', 'GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'36 PENCILS TUBE RED RETROSPOT', 'ROSES REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.873015873015873, lift=17.141810570382)]),
#  RelationRecord(items=frozenset({'36 PENCILS TUBE RED RETROSPOT', 'SUKI  SHOULDER BAG', 'SKULL SHOULDER BAG'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'36 PENCILS TUBE RED RETROSPOT', 'SKULL SHOULDER BAG'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.8484848484848485, lift=31.51918351918352)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', 'SUKI  SHOULDER BAG', '36 PENCILS TUBE SKULLS'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', '36 PENCILS TUBE SKULLS'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.8307692307692307, lift=30.86109067647529), OrderedStatistic(items_base=frozenset({'SUKI  SHOULDER BAG', '36 PENCILS TUBE SKULLS'}), items_add=frozenset({'SKULL SHOULDER BAG'}), confidence=0.8307692307692307, lift=39.37449500102019)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS', 'JAM MAKING SET PRINTED'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS'}), items_add=frozenset({'JAM MAKING SET PRINTED'}), confidence=0.8507462686567164, lift=15.511361559549192)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS', 'POPCORN HOLDER'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS'}), items_add=frozenset({'POPCORN HOLDER'}), confidence=0.8358208955223881, lift=19.22065348931021)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS', 'ROTATING LEAVES T-LIGHT HOLDER'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS'}), items_add=frozenset({'ROTATING LEAVES T-LIGHT HOLDER'}), confidence=0.8208955223880597, lift=54.52699328635633)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS', 'SKULL SHOULDER BAG'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS'}), items_add=frozenset({'SKULL SHOULDER BAG'}), confidence=0.8059701492537313, lift=38.19913694128825)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS', 'SUKI  SHOULDER BAG'}), support=0.003413924334004925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.9104477611940298, lift=33.820957582151614)]),
#  RelationRecord(items=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS', 'VINTAGE SNAP CARDS'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BUTTON BOX', '4 TRADITIONAL SPINNING TOPS'}), items_add=frozenset({'VINTAGE SNAP CARDS'}), confidence=0.8059701492537313, lift=17.648375768217736)]),
#  RelationRecord(items=frozenset({'SUKI  SHOULDER BAG', '4 TRADITIONAL SPINNING TOPS', 'CARD PSYCHEDELIC APPLES'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'CARD PSYCHEDELIC APPLES'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.8852459016393442, lift=32.884768753621216)]),
#  RelationRecord(items=frozenset({'4 TRADITIONAL SPINNING TOPS', 'GARDENERS KNEELING PAD CUP OF TEA', 'GARDENERS KNEELING PAD KEEP CALM'}), support=0.003413924334004925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'GARDENERS KNEELING PAD CUP OF TEA'}), items_add=frozenset({'GARDENERS KNEELING PAD KEEP CALM'}), confidence=0.8243243243243243, lift=16.275167985665224)]),
#  RelationRecord(items=frozenset({'4 TRADITIONAL SPINNING TOPS', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'PINK REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.8260869565217391, lift=16.220353559483993)]),
#  RelationRecord(items=frozenset({'JAM MAKING SET PRINTED', '4 TRADITIONAL SPINNING TOPS', 'ROTATING LEAVES T-LIGHT HOLDER'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'ROTATING LEAVES T-LIGHT HOLDER'}), items_add=frozenset({'JAM MAKING SET PRINTED'}), confidence=0.8028169014084506, lift=14.637482035067546)]),
#  RelationRecord(items=frozenset({'4 TRADITIONAL SPINNING TOPS', "PAPER CHAIN KIT 50'S CHRISTMAS", 'PAPER CHAIN KIT VINTAGE CHRISTMAS'}), support=0.0033019923886277143, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'PAPER CHAIN KIT VINTAGE CHRISTMAS'}), items_add=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS"}), confidence=0.8805970149253731, lift=16.039253274909854)]),
#  RelationRecord(items=frozenset({'4 TRADITIONAL SPINNING TOPS', 'ROTATING LEAVES T-LIGHT HOLDER', 'POPCORN HOLDER'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'ROTATING LEAVES T-LIGHT HOLDER'}), items_add=frozenset({'POPCORN HOLDER'}), confidence=0.8028169014084506, lift=18.46168905323835)]),
#  RelationRecord(items=frozenset({'SUKI  SHOULDER BAG', '4 TRADITIONAL SPINNING TOPS', 'ROTATING LEAVES T-LIGHT HOLDER'}), support=0.003413924334004925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'ROTATING LEAVES T-LIGHT HOLDER'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.8591549295774648, lift=31.915551521185325)]),
#  RelationRecord(items=frozenset({'4 TRADITIONAL SPINNING TOPS', 'VINTAGE SNAP CARDS', 'ROTATING LEAVES T-LIGHT HOLDER'}), support=0.0033019923886277143, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'ROTATING LEAVES T-LIGHT HOLDER'}), items_add=frozenset({'VINTAGE SNAP CARDS'}), confidence=0.8309859154929577, lift=18.196147473073736)]),
#  RelationRecord(items=frozenset({'4 TRADITIONAL SPINNING TOPS', 'VINTAGE SNAP CARDS', 'SET OF 60 I LOVE LONDON CAKE CASES'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'SET OF 60 I LOVE LONDON CAKE CASES'}), items_add=frozenset({'VINTAGE SNAP CARDS'}), confidence=0.8088235294117647, lift=17.710856401384085)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', '4 TRADITIONAL SPINNING TOPS', 'SUKI  SHOULDER BAG'}), support=0.003525856279382136, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', '4 TRADITIONAL SPINNING TOPS'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.8513513513513514, lift=31.625667247288874)]),
#  RelationRecord(items=frozenset({'4 TRADITIONAL SPINNING TOPS', 'WOODEN HEART CHRISTMAS SCANDINAVIAN', 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), support=0.003413924334004925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.9104477611940298, lift=34.984689455946075), OrderedStatistic(items_base=frozenset({'4 TRADITIONAL SPINNING TOPS', 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), confidence=0.8714285714285714, lift=31.64773519163763)]),
#  RelationRecord(items=frozenset({"ROLL WRAP 50'S RED CHRISTMAS", "6 GIFT TAGS 50'S CHRISTMAS", '6 GIFT TAGS VINTAGE CHRISTMAS'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({"ROLL WRAP 50'S RED CHRISTMAS", '6 GIFT TAGS VINTAGE CHRISTMAS'}), items_add=frozenset({"6 GIFT TAGS 50'S CHRISTMAS"}), confidence=0.823529411764706, lift=46.56589724497395)]),
#  RelationRecord(items=frozenset({'JUMBO BAG VINTAGE CHRISTMAS', "6 GIFT TAGS 50'S CHRISTMAS", "JUMBO BAG 50'S CHRISTMAS"}), support=0.0038056861428251623, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG VINTAGE CHRISTMAS', "6 GIFT TAGS 50'S CHRISTMAS"}), items_add=frozenset({"JUMBO BAG 50'S CHRISTMAS"}), confidence=0.8831168831168831, lift=22.256040151667797)]),
#  RelationRecord(items=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS", "6 GIFT TAGS 50'S CHRISTMAS", 'PAPER CHAIN KIT VINTAGE CHRISTMAS'}), support=0.0041974479516454, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PAPER CHAIN KIT VINTAGE CHRISTMAS', "6 GIFT TAGS 50'S CHRISTMAS"}), items_add=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS"}), confidence=0.9375, lift=17.075688073394495)]),
#  RelationRecord(items=frozenset({"ROLL WRAP 50'S CHRISTMAS", "6 GIFT TAGS 50'S CHRISTMAS", "ROLL WRAP 50'S RED CHRISTMAS"}), support=0.005372733378106112, ordered_statistics=[OrderedStatistic(items_base=frozenset({"ROLL WRAP 50'S RED CHRISTMAS", "6 GIFT TAGS 50'S CHRISTMAS"}), items_add=frozenset({"ROLL WRAP 50'S CHRISTMAS"}), confidence=0.888888888888889, lift=45.37904761904762)]),
#  RelationRecord(items=frozenset({"ROLL WRAP 50'S CHRISTMAS", "6 GIFT TAGS 50'S CHRISTMAS", 'ROLL WRAP VINTAGE CHRISTMAS'}), support=0.005092903514663085, ordered_statistics=[OrderedStatistic(items_base=frozenset({"6 GIFT TAGS 50'S CHRISTMAS", 'ROLL WRAP VINTAGE CHRISTMAS'}), items_add=frozenset({"ROLL WRAP 50'S CHRISTMAS"}), confidence=0.8348623853211009, lift=42.62091743119266)]),
#  RelationRecord(items=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', "6 GIFT TAGS 50'S CHRISTMAS", 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', "6 GIFT TAGS 50'S CHRISTMAS"}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.875, lift=33.62258064516129), OrderedStatistic(items_base=frozenset({"6 GIFT TAGS 50'S CHRISTMAS", 'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), confidence=0.875, lift=31.777439024390244)]),
#  RelationRecord(items=frozenset({'CARD CHRISTMAS VILLAGE', '6 GIFT TAGS VINTAGE CHRISTMAS', 'CARD MOTORBIKE SANTA'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'6 GIFT TAGS VINTAGE CHRISTMAS', 'CARD MOTORBIKE SANTA'}), items_add=frozenset({'CARD CHRISTMAS VILLAGE'}), confidence=0.8028169014084506, lift=67.98451371737534)]),
#  RelationRecord(items=frozenset({'JAM MAKING SET PRINTED', '6 GIFT TAGS VINTAGE CHRISTMAS', 'SKULL SHOULDER BAG'}), support=0.0033579583613163196, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', '6 GIFT TAGS VINTAGE CHRISTMAS'}), items_add=frozenset({'JAM MAKING SET PRINTED'}), confidence=0.8955223880597015, lift=16.327749010051782)]),
#  RelationRecord(items=frozenset({'JAM MAKING SET PRINTED', '6 GIFT TAGS VINTAGE CHRISTMAS', 'SUKI  SHOULDER BAG'}), support=0.003413924334004925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SUKI  SHOULDER BAG', '6 GIFT TAGS VINTAGE CHRISTMAS'}), items_add=frozenset({'JAM MAKING SET PRINTED'}), confidence=0.8970588235294118, lift=16.355762304921967)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', '6 GIFT TAGS VINTAGE CHRISTMAS', "JUMBO BAG 50'S CHRISTMAS"}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', '6 GIFT TAGS VINTAGE CHRISTMAS'}), items_add=frozenset({"JUMBO BAG 50'S CHRISTMAS"}), confidence=0.8059701492537313, lift=20.311811885565124)]),
#  RelationRecord(items=frozenset({'SUKI  SHOULDER BAG', '6 GIFT TAGS VINTAGE CHRISTMAS', "JUMBO BAG 50'S CHRISTMAS"}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SUKI  SHOULDER BAG', '6 GIFT TAGS VINTAGE CHRISTMAS'}), items_add=frozenset({"JUMBO BAG 50'S CHRISTMAS"}), confidence=0.823529411764706, lift=20.75433502032689)]),
#  RelationRecord(items=frozenset({'JUMBO BAG ALPHABET', 'JUMBO BAG RED RETROSPOT', '6 GIFT TAGS VINTAGE CHRISTMAS'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG ALPHABET', '6 GIFT TAGS VINTAGE CHRISTMAS'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8181818181818181, lift=7.524072427829504)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', 'JUMBO BAG APPLES', '6 GIFT TAGS VINTAGE CHRISTMAS'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', '6 GIFT TAGS VINTAGE CHRISTMAS'}), items_add=frozenset({'JUMBO BAG APPLES'}), confidence=0.8059701492537313, lift=14.938874094258995)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', 'JUMBO BAG RED RETROSPOT', '6 GIFT TAGS VINTAGE CHRISTMAS'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', '6 GIFT TAGS VINTAGE CHRISTMAS'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8059701492537313, lift=7.411772839354437)]),
#  RelationRecord(items=frozenset({'SUKI  SHOULDER BAG', 'JUMBO BAG RED RETROSPOT', '6 GIFT TAGS VINTAGE CHRISTMAS'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SUKI  SHOULDER BAG', '6 GIFT TAGS VINTAGE CHRISTMAS'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8088235294117647, lift=7.4380127758772066)]),
#  RelationRecord(items=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS", '6 GIFT TAGS VINTAGE CHRISTMAS', 'PAPER CHAIN KIT VINTAGE CHRISTMAS'}), support=0.004813073651220058, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PAPER CHAIN KIT VINTAGE CHRISTMAS', '6 GIFT TAGS VINTAGE CHRISTMAS'}), items_add=frozenset({"PAPER CHAIN KIT 50'S CHRISTMAS"}), confidence=0.8037383177570093, lift=14.639343793763754)]),
# ...
#  RelationRecord(items=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'VINTAGE PAISLEY STATIONERY SET', 'COLOURING PENCILS BROWN TUBE'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'COLOURING PENCILS BROWN TUBE'}), items_add=frozenset({'VINTAGE PAISLEY STATIONERY SET'}), confidence=0.8260869565217391, lift=36.901304347826084)]),
#  RelationRecord(items=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'FLORAL FOLK STATIONERY SET', 'ROTATING LEAVES T-LIGHT HOLDER'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'ROTATING LEAVES T-LIGHT HOLDER'}), items_add=frozenset({'FLORAL FOLK STATIONERY SET'}), confidence=0.8260869565217391, lift=37.368409466153004)]),
#  RelationRecord(items=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'FLORAL FOLK STATIONERY SET', 'WALL TIDY RETROSPOT'}), support=0.0036377882247593464, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'WALL TIDY RETROSPOT'}), items_add=frozenset({'FLORAL FOLK STATIONERY SET'}), confidence=0.8125, lift=36.753797468354435)]),
#  RelationRecord(items=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER'}), support=0.0036377882247593464, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'PINK REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.8333333333333333, lift=16.36263736263736)]),
#  RelationRecord(items=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER'}), support=0.004589209760465637, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'ROSES REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.891304347826087, lift=17.50090778786431)]),
#  RelationRecord(items=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG PINK VINTAGE PAISLEY'}), support=0.003413924334004925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'JUMBO BAG PINK VINTAGE PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8026315789473684, lift=7.381071051277188)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', 'BEADED CRYSTAL HEART PINK ON STICK', 'ROTATING LEAVES T-LIGHT HOLDER'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'ROTATING LEAVES T-LIGHT HOLDER'}), items_add=frozenset({'SKULL SHOULDER BAG'}), confidence=0.8115942028985508, lift=38.46569023180717)]),
#  RelationRecord(items=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'SMALL MARSHMALLOWS PINK BOWL', 'ROTATING LEAVES T-LIGHT HOLDER'}), support=0.003246026415939109, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'ROTATING LEAVES T-LIGHT HOLDER'}), items_add=frozenset({'SMALL MARSHMALLOWS PINK BOWL'}), confidence=0.8405797101449276, lift=34.52753623188406)]),
#  RelationRecord(items=frozenset({'SUKI  SHOULDER BAG', 'BEADED CRYSTAL HEART PINK ON STICK', 'ROTATING LEAVES T-LIGHT HOLDER'}), support=0.003581822252070741, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'ROTATING LEAVES T-LIGHT HOLDER'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.927536231884058, lift=34.45575341227515)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', 'BEADED CRYSTAL HEART PINK ON STICK', 'SUKI  SHOULDER BAG'}), support=0.004421311842399821, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SKULL SHOULDER BAG', 'BEADED CRYSTAL HEART PINK ON STICK'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.8586956521739131, lift=31.89849046370786)]),
#  RelationRecord(items=frozenset({'SKULL SHOULDER BAG', 'BEADED CRYSTAL HEART PINK ON STICK', 'URBAN BLACK RIBBONS'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'URBAN BLACK RIBBONS', 'BEADED CRYSTAL HEART PINK ON STICK'}), items_add=frozenset({'SKULL SHOULDER BAG'}), confidence=0.8382352941176471, lift=39.72835075674832)]),
#  RelationRecord(items=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'SMALL MARSHMALLOWS PINK BOWL', 'SMALL DOLLY MIX DESIGN ORANGE BOWL'}), support=0.004421311842399821, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'SMALL DOLLY MIX DESIGN ORANGE BOWL'}), items_add=frozenset({'SMALL MARSHMALLOWS PINK BOWL'}), confidence=0.8061224489795917, lift=33.1121745249824), OrderedStatistic(items_base=frozenset({'BEADED CRYSTAL HEART PINK ON STICK', 'SMALL MARSHMALLOWS PINK BOWL'}), items_add=frozenset({'SMALL DOLLY MIX DESIGN ORANGE BOWL'}), confidence=0.8586956521739131, lift=30.262670439927966)]),
#  RelationRecord(items=frozenset({'SUKI  SHOULDER BAG', 'BEADED CRYSTAL HEART PINK ON STICK', 'URBAN BLACK RIBBONS'}), support=0.003581822252070741, ordered_statistics=[OrderedStatistic(items_base=frozenset({'URBAN BLACK RIBBONS', 'BEADED CRYSTAL HEART PINK ON STICK'}), items_add=frozenset({'SUKI  SHOULDER BAG'}), confidence=0.9411764705882354, lift=34.96245566833802)]),
#  RelationRecord(items=frozenset({'GARDENERS KNEELING PAD CUP OF TEA', 'BEWARE OF THE CAT METAL SIGN', 'GARDENERS KNEELING PAD KEEP CALM'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'GARDENERS KNEELING PAD CUP OF TEA', 'BEWARE OF THE CAT METAL SIGN'}), items_add=frozenset({'GARDENERS KNEELING PAD KEEP CALM'}), confidence=0.8382352941176471, lift=16.54982125446864), OrderedStatistic(items_base=frozenset({'BEWARE OF THE CAT METAL SIGN', 'GARDENERS KNEELING PAD KEEP CALM'}), items_add=frozenset({'GARDENERS KNEELING PAD CUP OF TEA'}), confidence=0.8142857142857144, lift=19.296627510420617)]),
#  RelationRecord(items=frozenset({'BICYCLE PUNCTURE REPAIR KIT', 'CLASSIC CHROME BICYCLE BELL', 'CLASSIC BICYCLE CLIPS'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BICYCLE PUNCTURE REPAIR KIT', 'CLASSIC CHROME BICYCLE BELL'}), items_add=frozenset({'CLASSIC BICYCLE CLIPS'}), confidence=0.8870967741935485, lift=161.74127715602373), OrderedStatistic(items_base=frozenset({'CLASSIC CHROME BICYCLE BELL', 'CLASSIC BICYCLE CLIPS'}), items_add=frozenset({'BICYCLE PUNCTURE REPAIR KIT'}), confidence=0.859375, lift=134.69572368421052)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY', 'BIG DOUGHNUT FRIDGE MAGNETS'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'BIG DOUGHNUT FRIDGE MAGNETS'}), items_add=frozenset({'JUMBO SHOPPER VINTAGE RED PAISLEY'}), confidence=0.8181818181818181, lift=13.350933997509339)]),
#  RelationRecord(items=frozenset({'JUMBO BAG RED RETROSPOT', 'JUMBO BAG TOYS', 'BIG DOUGHNUT FRIDGE MAGNETS'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG TOYS', 'BIG DOUGHNUT FRIDGE MAGNETS'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.857142857142857, lift=7.882361591059479)]),
#  RelationRecord(items=frozenset({'JUMBO STORAGE BAG SUKI', 'JUMBO BAG WOODLAND ANIMALS', 'BIG DOUGHNUT FRIDGE MAGNETS'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG WOODLAND ANIMALS', 'BIG DOUGHNUT FRIDGE MAGNETS'}), items_add=frozenset({'JUMBO STORAGE BAG SUKI'}), confidence=0.859375, lift=13.846088818755636)]),
#  RelationRecord(items=frozenset({'JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO STORAGE BAG SUKI', 'BIG DOUGHNUT FRIDGE MAGNETS'}), support=0.003413924334004925, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO SHOPPER VINTAGE RED PAISLEY', 'BIG DOUGHNUT FRIDGE MAGNETS'}), items_add=frozenset({'JUMBO STORAGE BAG SUKI'}), confidence=0.8356164383561643, lift=13.463295329619426), OrderedStatistic(items_base=frozenset({'JUMBO STORAGE BAG SUKI', 'BIG DOUGHNUT FRIDGE MAGNETS'}), items_add=frozenset({'JUMBO SHOPPER VINTAGE RED PAISLEY'}), confidence=0.8591549295774648, lift=14.019525371406521)]),
#  RelationRecord(items=frozenset({'BIRD DECORATION GREEN POLKADOT', 'SMALL DOLLY MIX DESIGN ORANGE BOWL', 'SMALL MARSHMALLOWS PINK BOWL'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD DECORATION GREEN POLKADOT', 'SMALL DOLLY MIX DESIGN ORANGE BOWL'}), items_add=frozenset({'SMALL MARSHMALLOWS PINK BOWL'}), confidence=0.8870967741935485, lift=36.43826473859845), OrderedStatistic(items_base=frozenset({'BIRD DECORATION GREEN POLKADOT', 'SMALL MARSHMALLOWS PINK BOWL'}), items_add=frozenset({'SMALL DOLLY MIX DESIGN ORANGE BOWL'}), confidence=0.9649122807017544, lift=34.00602096958372)]),
#  RelationRecord(items=frozenset({'BIRD DECORATION GREEN POLKADOT', 'SMALL DOLLY MIX DESIGN ORANGE BOWL', 'VINTAGE PAISLEY STATIONERY SET'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD DECORATION GREEN POLKADOT', 'SMALL DOLLY MIX DESIGN ORANGE BOWL'}), items_add=frozenset({'VINTAGE PAISLEY STATIONERY SET'}), confidence=0.8709677419354839, lift=38.906129032258065)]),
#  RelationRecord(items=frozenset({'BIRD DECORATION GREEN POLKADOT', 'WALL TIDY RETROSPOT', 'VINTAGE PAISLEY STATIONERY SET'}), support=0.0031340944705618985, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD DECORATION GREEN POLKADOT', 'WALL TIDY RETROSPOT'}), items_add=frozenset({'VINTAGE PAISLEY STATIONERY SET'}), confidence=0.8888888888888888, lift=39.70666666666666)]),
#  RelationRecord(items=frozenset({'CHARLOTTE BAG SUKI DESIGN', 'BIRD HOUSE HOT WATER BOTTLE', 'BOX OF 24 COCKTAIL PARASOLS'}), support=0.00346989030669353, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'BOX OF 24 COCKTAIL PARASOLS'}), items_add=frozenset({'CHARLOTTE BAG SUKI DESIGN'}), confidence=0.8493150684931506, lift=18.68911532492071)]),
#  RelationRecord(items=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'PACK OF 72 RETROSPOT CAKE CASES', 'BOX OF 24 COCKTAIL PARASOLS'}), support=0.0033019923886277143, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'BOX OF 24 COCKTAIL PARASOLS'}), items_add=frozenset({'PACK OF 72 RETROSPOT CAKE CASES'}), confidence=0.8082191780821918, lift=12.217648285932828)]),
#  RelationRecord(items=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'BOX OF 24 COCKTAIL PARASOLS', 'RED RETROSPOT CHARLOTTE BAG'}), support=0.0033579583613163196, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'BOX OF 24 COCKTAIL PARASOLS'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.821917808219178, lift=15.171515906260613)]),
#  RelationRecord(items=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'BOX OF 24 COCKTAIL PARASOLS', 'WOODLAND CHARLOTTE BAG'}), support=0.003581822252070741, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'BOX OF 24 COCKTAIL PARASOLS'}), items_add=frozenset({'WOODLAND CHARLOTTE BAG'}), confidence=0.8767123287671234, lift=20.21302695536898)]),
#  RelationRecord(items=frozenset({'CHARLOTTE BAG SUKI DESIGN', 'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT'}), support=0.004421311842399821, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'CHARLOTTE BAG SUKI DESIGN'}), confidence=0.9186046511627907, lift=20.213827471646237), OrderedStatistic(items_base=frozenset({'CHARLOTTE BAG SUKI DESIGN', 'BIRD HOUSE HOT WATER BOTTLE'}), items_add=frozenset({'CHARLOTTE BAG PINK POLKADOT'}), confidence=0.8144329896907216, lift=21.090273419991036)]),
#  RelationRecord(items=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT', 'PACK OF 72 RETROSPOT CAKE CASES'}), support=0.0039735840608909785, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'PACK OF 72 RETROSPOT CAKE CASES'}), confidence=0.8255813953488372, lift=12.480108605831662)]),
#  RelationRecord(items=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG'}), support=0.004365345869711216, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.9069767441860466, lift=16.741591389582933), OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'RED RETROSPOT CHARLOTTE BAG'}), items_add=frozenset({'CHARLOTTE BAG PINK POLKADOT'}), confidence=0.8387096774193549, lift=21.718934081346426)]),
#  RelationRecord(items=frozenset({'RED RETROSPOT OVEN GLOVE', 'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT'}), support=0.0030781284978732932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'RED RETROSPOT OVEN GLOVE', 'BIRD HOUSE HOT WATER BOTTLE'}), items_add=frozenset({'CHARLOTTE BAG PINK POLKADOT'}), confidence=0.8208955223880597, lift=21.257624918883845)]),
#  RelationRecord(items=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT', 'STRAWBERRY CHARLOTTE BAG'}), support=0.004085516006268189, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'STRAWBERRY CHARLOTTE BAG'}), confidence=0.8488372093023256, lift=22.536438715919694), OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'STRAWBERRY CHARLOTTE BAG'}), items_add=frozenset({'CHARLOTTE BAG PINK POLKADOT'}), confidence=0.8588235294117647, lift=22.23979539641944)]),
#  RelationRecord(items=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT', 'WOODLAND CHARLOTTE BAG'}), support=0.004365345869711216, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'WOODLAND CHARLOTTE BAG'}), confidence=0.9069767441860466, lift=20.91078769692423), OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'WOODLAND CHARLOTTE BAG'}), items_add=frozenset({'CHARLOTTE BAG PINK POLKADOT'}), confidence=0.8297872340425532, lift=21.487881591119333)]),
#  RelationRecord(items=frozenset({'CHARLOTTE BAG SUKI DESIGN', 'CIRCUS PARADE LUNCH BOX', 'BIRD HOUSE HOT WATER BOTTLE'}), support=0.0030221625251846875, ordered_statistics=[OrderedStatistic(items_base=frozenset({'CIRCUS PARADE LUNCH BOX', 'BIRD HOUSE HOT WATER BOTTLE'}), items_add=frozenset({'CHARLOTTE BAG SUKI DESIGN'}), confidence=0.9473684210526315, lift=20.846772102670467)]),
#  RelationRecord(items=frozenset({'CHARLOTTE BAG SUKI DESIGN', 'BIRD HOUSE HOT WATER BOTTLE', 'HOT BATHS METAL SIGN'}), support=0.0031900604432505038, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'HOT BATHS METAL SIGN'}), items_add=frozenset({'CHARLOTTE BAG SUKI DESIGN'}), confidence=0.9047619047619048, lift=19.909218859957775)]),
#  RelationRecord(items=frozenset({'CHARLOTTE BAG SUKI DESIGN', 'BIRD HOUSE HOT WATER BOTTLE', 'LUNCH BAG CARS BLUE'}), support=0.003581822252070741, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BIRD HOUSE HOT WATER BOTTLE', 'LUNCH BAG CARS BLUE'}), items_add=frozenset({'CHARLOTTE BAG SUKI DESIGN'}), confidence=0.8205128205128205, lift=18.055323986358466)]),
#  ...]

# %%
def inspect(results):
    lhs=[tuple(result[2][0][0])[0] for result in results]
    rhs=[tuple(result[2][0][1])[0] for result in results]
    supports=[result[1] for result in results]
    confidences=[result[2][0][2] for result in results]
    lifts=[result[2][0][3] for result in results]

    return list(zip(lhs,rhs,supports,confidences,lifts))

# %%
result=pd.DataFrame(inspect(results),columns=['Left Hand Side','Right Hand Side','Support','Confidence','Lift'])
result.sort_values(by='Confidence',ascending=False)
# Out:
#                       Left Hand Side                     Right Hand Side  \
# 188        BIRTHDAY CARD, RETRO SPOT                  SUKI  SHOULDER BAG
# 1672                      BUTTON BOX                  SUKI  SHOULDER BAG
# 863   ASSORTED TUTTI FRUTTI BRACELET                  SUKI  SHOULDER BAG
# 5975              PIZZA PLATE IN BOX  WOODEN STAR CHRISTMAS SCANDINAVIAN
# 271         TOAST ITS - FAIRY FLOWER                  SUKI  SHOULDER BAG
# ...                              ...                                 ...
# 4357            HOT BATHS METAL SIGN            RED RETROSPOT OVEN GLOVE
# 1940          WOODLAND CHARLOTTE BAG                  SUKI  SHOULDER BAG
# 1811             CARD BILLBOARD FONT     GREEN REGENCY TEACUP AND SAUCER
# 5919   SET/6 RED SPOTTY PAPER PLATES  SET/20 RED RETROSPOT PAPER NAPKINS
# 1366     BOX OF 24 COCKTAIL PARASOLS     PACK OF 72 RETROSPOT CAKE CASES
#
#        Support  Confidence       Lift
# 188   0.003078         1.0  37.147609
# 1672  0.004141         1.0  37.147609
# 863   0.003078         1.0  37.147609
# 5975  0.003134         1.0  38.425806
# 271   0.003526         1.0  37.147609
# ...        ...         ...        ...
# 4357  0.003134         0.8  36.096970
# 1940  0.004253         0.8  29.718087
# 1811  0.003582         0.8  15.708132
# 5919  0.004477         0.8  15.829900
# 1366  0.003582         0.8  12.093401
#
# [6729 rows x 5 columns]
